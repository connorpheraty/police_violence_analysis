# %%
import pandas as pd

# %%
df = pd.read_csv("police_violence.csv")

# %%
df.count()
# Out:
# State                                                            100
# City                                                             100
# PD                                                               100
# Black People Killed by Police (1/1/2013-12/31/2019)               91
# Hispanic People Killed by Police (1/1/2013-12/31/2019)            69
# Native American People Killed by Police (1/1/2013-12/31/2019)     10
# Asian People Killed by Police (1/1/2013-12/31/2019)               30
# Pacific Islanders Killed by Police (1/1/2013-12/31/2019)           7
# White People Killed by Police (1/1/2013-12/31/2019)               89
# Unknown Race People Killed by Police (1/1/2013-12/31/2019)        54
# Total                                                            100
# Black                                                            100
# White                                                            100
# Amer. Indian                                                     100
# ...

# %%
df.columns
# Out:
# Index(['State', 'City', 'PD',
#        'Black People Killed by Police (1/1/2013-12/31/2019)',
#        'Hispanic People Killed by Police (1/1/2013-12/31/2019)',
#        'Native American People Killed by Police (1/1/2013-12/31/2019)',
#        'Asian People Killed by Police (1/1/2013-12/31/2019)',
#        'Pacific Islanders Killed by Police (1/1/2013-12/31/2019)',
#        'White People Killed by Police (1/1/2013-12/31/2019)',
#        'Unknown Race People Killed by Police (1/1/2013-12/31/2019)', 'Total',
#        'Black', 'White', 'Amer. Indian', 'Asian', 'Hawaiian', 'Other',
#        'Two or\nmore races', 'Hispanic',
#        'Black-White Dissimilarity Index (2010)',
#        'Murder and\nnonnegligent manslaughter',
#        'Violent crimes 2013 (if reported by agency)',
#        'Violent crimes 2014 (if reported by agency)',
#        'Violent crimes 2015 (if reported by agency)',
#        'Violent crimes 2016 (if reported by agency)',
# ...

# %%
kbp = df[['State', 'City', 'Black People Killed by Police (1/1/2013-12/31/2019)', 'Hispanic People Killed by Police (1/1/2013-12/31/2019)', 'Native American People Killed by Police (1/1/2013-12/31/2019)', 'Asian People Killed by Police (1/1/2013-12/31/2019)', 'Pacific Islanders Killed by Police (1/1/2013-12/31/2019)', 'White People Killed by Police (1/1/2013-12/31/2019)', 'Total',
       'Black', 'White', 'Amer. Indian', 'Asian', 'Hawaiian', 'Other',
       'Two or\nmore races', 'Hispanic',]]

# %%
kbp
# Out:
#              State            City  \
# 0       New Mexico     Albuquerque
# 1       California         Anaheim
# 2           Alaska       Anchorage
# 3            Texas       Arlington
# 4          Georgia         Atlanta
# ..             ...             ...
# 95         Arizona          Tucson
# 96        Oklahoma           Tulsa
# 97        Virginia  Virginia Beach
# 98          Kansas         Wichita
# 99  North Carolina   Winston-Salem
#
#     Black People Killed by Police (1/1/2013-12/31/2019)  \
# 0                                                 3.0
# 1                                                 3.0
# 2                                                 1.0
# 3                                                 7.0
# 4                                                13.0
# ..                                                ...
# 95                                                2.0
# 96                                                7.0
# ...

# %%
kbp = kbp.sort_values(by=['Black People Killed by Police (1/1/2013-12/31/2019)'], ascending=False).head(10)

# %%
kbp["City"]
# Out:
# 16          Chicago
# 62         New York
# 89        St. Louis
# 39          Houston
# 21         Columbus
# 51      Los Angeles
# 8         Baltimore
# 67    Oklahoma City
# 70     Philadelphia
# 43     Jacksonville
# Name: City, dtype: object

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
